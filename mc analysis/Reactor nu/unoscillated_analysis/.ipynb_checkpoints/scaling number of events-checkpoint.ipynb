# %% [markdown]
# # Notebook Dedicated to Re-scale the Number of Simulated Reactor Antinu Events to the number of Events Expected in the Livetime of the Real Data set

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

from scipy.special import factorial
from lmfit import Model
from scipy.optimize import curve_fit

import pandas as pd

import glob

# %% [markdown]
# # Load Data
#
# Lets read the data as follows:
# 1) Create a list of the main folders output_0, output_1, ...
# 2) Create a list with the file names of the observables to be readen
# 3) Take the ith diretory of the list of main folders, and join it to the observable name list to be readen and save the observables values for each iteration over output_i folders

# %%
# ======= Cuts on Data Observables =======

energy_delay_sup_cut = 2.3
energy_delay_inf_cut = 1.9

dt_sup_lim = 1000
dt_inf_lim = 0.5

dr_sup_lim = 900

# ========================================

#Main Data Directory
main_dir = 'E:/Data/antinu/mc/reactor_nu/out_results/'
folder_name_pattern = 'output_*/'

main_dir_list = glob.glob(main_dir + folder_name_pattern)
main_dir_list

#Observable file names to be readen
obs_real_list = ['dt', 'dr', 'energy_prompt', 'energy_delay']

#Dictionary with empty np.arrays of the observables to be readen
observable_dict = {obs_i : np.array([]) for obs_i in obs_real_list}

#Iteration over main directory list
for main_dir_list_i in main_dir_list:
    print(f'reading folder {main_dir_list_i}')
    #Create the directories for the observables (defined along the next iteration) to be readen using the main_dir_list_i and save its value
    for obs_i in obs_real_list:
        print(f'saving information of observable {obs_i}')
        dir_obs_i = main_dir_list_i + obs_i + '.npy'  #Create the full directory of the observable 
        array_obs_i = np.load(dir_obs_i)              #Load the numpy array of the corresponding observable obs_i
        observable_dict[str(obs_i)] = np.append(observable_dict[str(obs_i)], array_obs_i)  #Save the observable in the dictionary


#Define energy cut on prompt and delay to plot. In the MC data is seen how there are energy values higher than 8 MeV
#Extract energy arrays to perform cuts
energy_prompt = observable_dict['energy_prompt']
energy_delay = observable_dict['energy_delay'] #Limit energy delay, but this is strange to be larger ...
dt = observable_dict['dt']
dr = observable_dict['dr']

cut_condition = (energy_prompt <= energy_prompt_sup_cut) & (energy_delay <= energy_delay_sup_cut) & (dt > dt_inf_lim) & (dt <= dt_sup_lim) & (dr <= dr_sup_lim)

energy_prompt = energy_prompt[cut_condition]
energy_delay = energy_delay[cut_condition]
dt = dt[cut_condition]
dr = dr[cut_condition]
# Out:
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_0\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_1\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_10\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_11\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_12\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_13\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_14\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_15\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_16\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_17\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_18\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_19\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_2\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_20\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_21\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_22\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_23\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_24\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_25\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_26\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_27\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_28\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_29\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_3\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_30\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_31\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_32\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_33\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_34\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_35\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_36\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_37\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_38\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_39\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_4\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_40\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_41\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_42\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_43\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_44\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_45\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_46\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_47\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_48\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_49\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_5\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_50\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_51\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_52\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_53\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_54\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_55\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_56\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_57\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_58\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_59\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_6\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_60\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_61\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_62\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_63\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_64\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_65\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_66\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_67\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_68\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_69\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_7\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_70\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_71\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_72\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_73\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_74\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_8\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay
# reading folder E:/Data/antinu/mc/reactor_nu/out_results\output_9\
# saving information of observable dt
# saving information of observable dr
# saving information of observable energy_prompt
# saving information of observable energy_delay

# %% [markdown]
# # Scale the Number of Events

# %% [markdown]
# ## Nº of Events Calculation

# %%
# ======= Livetime Values =======
N_exp_ev_per_day = 27.9/134.4  # Nº of expected reactor antinu events per day

dataset_tot_lf = 237.16 # Nº of Days of the raw real dataset (only cuts on scintfit, fitvalid, dcflag and nhits)
cut_time = 29.44 # Nº of days to be removed from the dataset_tot_lf due to run cuts, hotsposts and atmospherics

total_lf = dataset_tot_lf - cut_time  # Total livetime of the raw dataset

N_scaled_mc_ev = total_lf * N_exp_ev_per_day # Nº of expected reactor antinu events during the total livetime of the real Dataset
N_scaled_mc_ev
# Out:
# 43.12044642857143

# %% [markdown]
# ## MC Events Selection
#
# Now the idea is to select N_scaled_mc_ev events in order to directly compare with the real data analysis results. The next steps must be followed:
# 1) Define the number of events we want to pick from the MC data;
# 2) Arange the data by ([energy_prompt, energy_delay], dt, dr)
# 3) Select events randomly and uniformly;

# %%
N_mc_ev = len(energy_prompt) # Number of MC events
rng = np.random.default_rng(seed=12345)  # Create a seed generator to reproduce the random choice

# Create random indices and pick the MC events
indices = rng.choice(N_mc_ev, size = int(N_scaled_mc_ev), replace = False)

energy_prompt_scaled = energy_prompt[indices]
energy_delay_scaled  = energy_delay[indices]
dr_scaled            = dr[indices]
dt_scaled            = dt[indices]

# %%
binwidth_prompt = 0.5
binwidth_delay = 0.04

fig, axes = plt.subplots(1, 2,  figsize=(18, 5.8))

sn.histplot(energy_prompt_scaled, ax = axes[0],  binwidth = binwidth_prompt, color = 'black', element = 'step', alpha = 0)
sn.histplot(energy_delay_scaled, ax = axes[1], binwidth = binwidth_delay, color = 'black', element = 'step', alpha = 0)

axes[0].set_xlabel('Prompt Energy (MeV)')
#axes[0].set_yscale('log')

axes[1].set_xlabel('Delay Energy (MeV)')
#axes[1].set_yscale('log')

plt.suptitle(r"MC Reactor $\bar{\nu}$  - Energy of Scaled Events", fontsize = 12)
#plt.savefig(save_dir + 'prompt and delay energy/energy_' + main_title_save+'.png', format = 'png', bbox_inches = 'tight')

plt.show()
